# %%
import numpy as np

# %%
# 生成特征
x1 = np.random.randn(100)
print(np.var(x1))
# Out:
# 0.7593106023277016

# %%
x2 = np.random.normal(5, 0.1, 100)
print(np.var(x2))
# Out:
# 0.008880331676347282

# %%
# 将特征组合为矩阵
X = np.vstack((x1, x2)).T
print(X.shape)
# Out:
# (100, 2)

# %%
# 特征选中，低方差过滤
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(threshold=0.01)
X_filtered = vt.fit_transform(X)
